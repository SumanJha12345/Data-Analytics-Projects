# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading The Dataset

# %%
sj=pd.read_csv('winequalityN.csv')
print(sj)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
sj.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
sj.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
sj.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
sj.shape
# Out:
# (6497, 13)

# %%
sj.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
sj.index
# Out:
# RangeIndex(start=0, stop=6497, step=1)

# %%
sj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %% [markdown]
# ## Preprocessing The Data

# %%
#Check for null values
sj.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
sj["fixed acidity"].value_counts()
# Out:
# 6.80     354
# 6.60     326
# 6.40     305
# 7.00     282
# 6.90     279
#         ...
# 3.90       1
# 3.80       1
# 6.45       1
# 4.50       1
# 12.10      1
# Name: fixed acidity, Length: 106, dtype: int64

# %%
mean = sj["fixed acidity"].mean()
sj["fixed acidity"].fillna(mean,inplace=True)
sj["fixed acidity"].isnull().sum()
# Out:
# 0

# %%
sj["volatile acidity"].value_counts()
# Out:
# 0.280    286
# 0.240    265
# 0.260    255
# 0.250    238
# 0.220    235
#         ...
# 0.975      1
# 1.070      1
# 0.950      1
# 1.090      1
# 0.905      1
# Name: volatile acidity, Length: 187, dtype: int64

# %%
mean = sj["volatile acidity"].mean()
sj["volatile acidity"].fillna(mean,inplace=True)
sj["volatile acidity"].isnull().sum()
# Out:
# 0

# %%
sj["citric acid"].value_counts()
# Out:
# 0.30    337
# 0.28    301
# 0.32    289
# 0.49    283
# 0.26    257
#        ...
# 1.66      1
# 1.23      1
# 0.99      1
# 0.88      1
# 0.75      1
# Name: citric acid, Length: 89, dtype: int64

# %%
mean = sj["citric acid"].mean()
sj["citric acid"].fillna(mean,inplace=True)
sj["citric acid"].isnull().sum()
# Out:
# 0

# %%
sj["residual sugar"].value_counts()
# Out:
# 2.00     235
# 1.80     228
# 1.60     223
# 1.40     219
# 1.20     195
#         ...
# 12.05      1
# 6.95       1
# 9.55       1
# 20.15      1
# 3.45       1
# Name: residual sugar, Length: 316, dtype: int64

# %%
mean = sj["residual sugar"].mean()
sj["residual sugar"].fillna(mean,inplace=True)
sj["residual sugar"].isnull().sum()
# Out:
# 0

# %%
sj["chlorides"].value_counts()
# Out:
# 0.044    206
# 0.036    200
# 0.042    187
# 0.046    185
# 0.050    182
#         ...
# 0.610      1
# 0.290      1
# 0.360      1
# 0.239      1
# 0.230      1
# Name: chlorides, Length: 214, dtype: int64

# %%
mean = sj["chlorides"].mean()
sj["chlorides"].fillna(mean,inplace=True)
sj["chlorides"].isnull().sum()
# Out:
# 0

# %%
sj["pH"].value_counts()
# Out:
# 3.16    200
# 3.14    193
# 3.22    185
# 3.20    176
# 3.15    170
#        ...
# 2.72      1
# 3.85      1
# 3.82      1
# 3.81      1
# 3.79      1
# Name: pH, Length: 108, dtype: int64

# %%
mean = sj["pH"].mean()
sj["pH"].fillna(mean,inplace=True)
sj["pH"].isnull().sum()
# Out:
# 0

# %%
sj["sulphates"].value_counts()
# Out:
# 0.50    275
# 0.46    243
# 0.54    234
# 0.44    232
# 0.38    214
#        ...
# 1.20      1
# 1.56      1
# 0.23      1
# 0.22      1
# 1.33      1
# Name: sulphates, Length: 111, dtype: int64

# %%
mean = sj["sulphates"].mean()
sj["sulphates"].fillna(mean,inplace=True)
sj["sulphates"].isnull().sum()
# Out:
# 0

# %%
sj.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sj['type'].value_counts()
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### (1)Quantitative Analysis

# %%
# Compute the mean of the quality column
quality_mean = sj['quality'].mean()
print('Mean:', quality_mean)
# Out:
# Mean: 5.818377712790519

# %%
# Compute the median of the quality column
quality_median = sj['quality'].median()
print('Median:', quality_median)
# Out:
# Median: 6.0

# %%
# Compute the mode of the quality column
quality_mode = sj['quality'].mode()[0]
print('Mode:', quality_mode)
# Out:
# Mode: 6

# %%
# Compute the standard deviation of the quality column
quality_std = sj['quality'].std()
print('Standard deviation:', quality_std)
# Out:
# Standard deviation: 0.8732552715311137

# %%
# Compute the skewness of the quality column
import pandas as pd
from scipy.stats import skew
quality_skewness = skew(sj['quality'])
print('Skewness:', quality_skewness)
# Out:
# Skewness: 0.18957891127582205

# %%
# Data normalization
sj = (sj - sj.mean()) / sj.std()
print(sj)
# Out:
#        alcohol  chlorides  citric acid   density  fixed acidity  \
# 0    -1.418449  -0.315198     0.284223  2.102052      -0.167146
# 1    -0.831551  -0.201012     0.146512 -0.232314      -0.707373
# 2    -0.328496  -0.172465     0.559646  0.134515       0.681783
# 3    -0.496181   0.055906     0.008800  0.301255      -0.012795
# 4    -0.496181   0.055906     0.008800  0.301255      -0.012795
# ...        ...        ...          ...       ...            ...
# 6492  0.006874   0.969392    -1.643736  0.067819      -0.784548
# 6493  0.593772   0.170092    -1.506025  0.141185      -1.016074
# 6494  0.426087   0.569742    -1.299458  0.347943      -0.707373
# 6495 -0.244653   0.541196    -1.368314  0.257903      -1.016074
# 6496  0.426087   0.312824     1.041636  0.264572      -0.938899
#
#       free sulfur dioxide        pH   quality  residual sugar     sulphates  \
# 0                0.815503 -1.359560  0.207983        3.206730 -5.459171e-01
# ...

# %%
# Feature selection
selected_features = ['alcohol', 'volatile acidity', 'sulphates', 'pH', 'quality']
sj = sj[selected_features]
sj
# Out:
#        alcohol  volatile acidity     sulphates        pH   quality
# 0    -1.418449         -0.423531 -5.459171e-01 -1.359560  0.207983
# 1    -0.831551         -0.241213 -2.770426e-01  0.508006  0.207983
# 2    -0.328496         -0.362758 -6.131357e-01  0.258997  0.207983
# 3    -0.496181         -0.666622 -8.820102e-01 -0.176768  0.207983
# 4    -0.496181         -0.666622 -8.820102e-01 -0.176768  0.207983
# ...        ...               ...           ...       ...       ...
# 6492  0.006874          1.581968  3.279250e-01  1.441789 -0.937157
# 6493  0.593772          1.278104  7.462766e-16  1.877554  0.207983
# 6494  0.426087          1.035013  1.470642e+00  1.255032  0.207983
# 6495 -0.244653          1.855445  1.201767e+00  2.188815 -0.937157
# 6496  0.426087         -0.180440  8.656740e-01  1.068276  0.207983
#
# [6497 rows x 5 columns]

# %%
# Feature engineering
sj['alcohol_squared'] = sj['alcohol'] ** 2
sj
# Out:
#        alcohol  volatile acidity     sulphates        pH   quality  \
# 0    -1.418449         -0.423531 -5.459171e-01 -1.359560  0.207983
# 1    -0.831551         -0.241213 -2.770426e-01  0.508006  0.207983
# 2    -0.328496         -0.362758 -6.131357e-01  0.258997  0.207983
# 3    -0.496181         -0.666622 -8.820102e-01 -0.176768  0.207983
# 4    -0.496181         -0.666622 -8.820102e-01 -0.176768  0.207983
# ...        ...               ...           ...       ...       ...
# 6492  0.006874          1.581968  3.279250e-01  1.441789 -0.937157
# 6493  0.593772          1.278104  7.462766e-16  1.877554  0.207983
# 6494  0.426087          1.035013  1.470642e+00  1.255032  0.207983
# 6495 -0.244653          1.855445  1.201767e+00  2.188815 -0.937157
# 6496  0.426087         -0.180440  8.656740e-01  1.068276  0.207983
#
#       alcohol_squared
# 0            2.011998
# 1            0.691477
# 2            0.107910
# 3            0.246196
# 4            0.246196
# ...

# %% [markdown]
# ### (2) Analysis using Visualization

# %%
# explore the data
print(sj.head()) # check the first few rows
print(sj.describe()) # get summary statistics
# Out:
#     alcohol  volatile acidity  sulphates        pH   quality  alcohol_squared
# 0 -1.418449         -0.423531  -0.545917 -1.359560  0.207983         2.011998
# 1 -0.831551         -0.241213  -0.277043  0.508006  0.207983         0.691477
# 2 -0.328496         -0.362758  -0.613136  0.258997  0.207983         0.107910
# 3 -0.496181         -0.666622  -0.882010 -0.176768  0.207983         0.246196
# 4 -0.496181         -0.666622  -0.882010 -0.176768  0.207983         0.246196
#             alcohol  volatile acidity     sulphates            pH  \
# count  6.497000e+03      6.497000e+03  6.497000e+03  6.497000e+03
# mean  -4.818722e-14     -4.633763e-15 -9.945818e-15  2.550724e-14
# std    1.000000e+00      1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.089189e+00     -1.578212e+00 -2.091945e+00 -3.102621e+00
# 25%   -8.315512e-01     -6.666217e-01 -6.803543e-01 -6.747858e-01
# 50%   -1.608107e-01     -3.019856e-01 -1.426053e-01 -5.226382e-02
# ...

# %%
#histogram
# create a histogram of the quality variable
sns.histplot(sj['quality'], kde=False)
plt.title('Distribution of Wine Quality')
plt.show()

# %%
#bar plot
# create a bar plot of wine quality
quality_counts = sj['quality'].value_counts()
quality_counts.plot(kind='bar')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Wine Quality')
plt.show()

# %%
#scatter plot
# create a scatter plot of alcohol vs. quality
sns.scatterplot(x='alcohol', y='quality', data=sj)
plt.title('Alcohol vs. Wine Quality')
plt.show()

# %%
# Create a clustermap to visualize the hierarchical clustering of different variabl
sns.clustermap(data=sj.corr(), cmap='coolwarm', annot=True)

# %%
#histogram
plt.hist(sj['quality'], bins=6, edgecolor='black')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Histogram of Wine Quality')
plt.show()

# %%
#line plot
# create a line plot of quality vs. alcohol
plt.plot(sj['alcohol'], sj['quality'], marker='o', linestyle='--')
plt.title('Wine Quality vs. Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#area plot
# Load the wine quality dataset
# Group the data by wine type and calculate the mean quality score
sj = pd.read_csv('winequalityN.csv')
sj_grouped = sj.groupby('type')['quality'].mean()
# Create an area plot
sj_grouped.plot(kind='area', stacked=False)
# Add labels and title
plt.xlabel('Wine Type')
plt.ylabel('Mean Quality Score')
plt.title('Mean Quality Score by Wine Type')
# Show the plot
plt.show()

# %%
#stacked bar plot
# create a cross-tabulation of wine type and quality
ct = pd.crosstab(sj['type'], sj['quality'])
ct.plot(kind='bar', stacked=True)
plt.title('Wine Type vs. Quality')
plt.xlabel('Wine Type')
plt.ylabel('Number of Samples')
plt.show()

# %%
#pie chart
# Count the number of wines for each quality score
quality_counts = sj['quality'].value_counts()
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%')
plt.title('Wine Quality Distribution')
plt.show()

# %%
#Scatter plot
# Create the figure and axes objects
fig, ax = plt.subplots()
x_data = sj['alcohol']
y_data = sj['quality']
ax.scatter(x_data, y_data)
ax.set_xlabel('Alcohol Content')
ax.set_ylabel('Quality Rating')
plt.show()

# %%
#box plot
# create a box plot
fig, ax = plt.subplots(figsize=(10, 6))
sj.boxplot(column=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
 'pH', 'sulphates', 'alcohol'], ax=ax)
ax.set_title('Box plot for wine quality attributes')
ax.set_ylabel('Attribute values')
plt.show()

# %%
#histplot
# Visualize the distribution of alcohol content using a histogram
sns.histplot(data=sj, x='alcohol', hue='type', kde=True)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
#bubble plot
# Create bubble plot
plt.scatter(sj['alcohol'], sj['volatile acidity'], s=sj['quality']*50, alpha=0.5)
plt.xlabel('Alcohol')
plt.ylabel('Volatile Acidity')
plt.title('Wine Quality')
plt.show()

# %%
#scatter plot
# Create a scatter plot using Seaborn
sns.scatterplot(data=sj, x="alcohol", y="quality", hue="type")
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
#violinplot
sns.violinplot(x='quality', y='alcohol', data=sj)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# #### We can see that there are Some outliers.So now let's remove those Outliers

# %%
lower_limit = sj["free sulfur dioxide"].mean() - 3*sj["free sulfur dioxide"].std()
upper_limit = sj["free sulfur dioxide"].mean() + 3*sj["free sulfur dioxide"].std()

# %%
print(lower_limit,upper_limit)
# Out:
# -22.722879937833156 83.77351869418224

# %%
sj2 = sj[(sj["free sulfur dioxide"] > lower_limit) & (sj["free sulfur dioxide"] < upper_limit)]

# %%
sj.shape[0] - sj2.shape[0]
# Out:
# 36

# %%
lower_limit = sj2['total sulfur dioxide'].mean() - 3*sj2['total sulfur dioxide'].std()
upper_limit = sj2['total sulfur dioxide'].mean() + 3*sj2['total sulfur dioxide'].std()
print(lower_limit,upper_limit)
# Out:
# -53.15243132839596 283.65436601342924

# %%
sj3 = sj2[(sj2['total sulfur dioxide'] > lower_limit) & (sj2['total sulfur dioxide'] < upper_limit)]
sj3.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
sj2.shape[0] - sj3.shape[0]
# Out:
# 5

# %%
lower_limit = sj3['residual sugar'].mean() - 3*sj3['residual sugar'].std()
upper_limit = sj3['residual sugar'].mean() + 3*sj3['residual sugar'].std()
print(lower_limit,upper_limit)
# Out:
# -8.838077345045534 19.714650013158373

# %%
sj4= sj3[(sj3['residual sugar'] > lower_limit) & (sj3['residual sugar']<upper_limit)]
sj4.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
# 5      0.050                 30.0                  97.0   0.9951  3.26
#
#    sulphates  alcohol  quality
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# ...

# %%
sj3.shape[0] - sj4.shape[0]
# Out:
# 28

# %%
sj4.dropna(inplace=True)

# %%
sj4.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dummies = pd.get_dummies(sj4["type"],drop_first=True)

# %%
sj4 = pd.concat([sj4,dummies],axis=1)

# %%
sj4.drop("type",axis=1,inplace=True)

# %%
sj4.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality  white
# 1      9.5        6      1
# 2     10.1        6      1
# ...

# %%
sj4.quality.value_counts()
# Out:
# 6    2790
# 5    2106
# 7    1070
# 4     212
# 8     188
# 3      25
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# #### Now lets Change the Categorical 'String' Variables into Numerical Variables

# %%
quaity_mapping = { 3 : "Low",4 : "Low",5: "Medium",6 : "Medium",7: "Medium",8 : "High",9 : "High"}
sj4["quality"] =  sj4["quality"].map(quaity_mapping)

# %%
sj4.quality.value_counts()
# Out:
# Medium    5966
# Low        237
# High       193
# Name: quality, dtype: int64

# %%
sj4.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol quality  white
# 1      9.5  Medium      1
# 2     10.1  Medium      1
# ...

# %%
mapping_quality = {"Low" : 0,"Medium": 1,"High" : 2}
sj4["quality"] =  sj4["quality"].map(mapping_quality)

# %%
sj4.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality  white
# 1      9.5        1      1
# 2     10.1        1      1
# ...

# %% [markdown]
# #### Lets Select the best Features for our Model

# %%
x = sj4.drop("quality",axis=True)
y = sj4["quality"]

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.08451229 0.10731956 0.08491186 0.08987758 0.08476521 0.1009888
#  0.08832552 0.08657824 0.08418449 0.08706362 0.09222029 0.00925253]

# %%
feat_importances = pd.Series(model.feature_importances_,index =x.columns)
feat_importances.nlargest(9).plot(kind="barh")
plt.show()

# %% [markdown]
# #### Now Let's select the best model for our Dataset

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
model_params  = {
    "svm" : {
        "model":SVC(gamma="auto"),
        "params":{
            'C' : [1,10,20],
            'kernel':["rbf"]
        }
    },
    
    "decision_tree":{
        "model": DecisionTreeClassifier(),
        "params":{
            'criterion':["entropy","gini"],
            "max_depth":[5,8,9]
        }
    },
    
    "random_forest":{
        "model": RandomForestClassifier(),
        "params":{
            "n_estimators":[1,5,10],
            "max_depth":[5,8,9]
        }
    },
    "naive_bayes":{
        "model": GaussianNB(),
        "params":{}
    },
    
    'logistic_regression' : {
        'model' : LogisticRegression(solver='liblinear',multi_class = 'auto'),
        'params': {
            "C" : [1,5,10]
        }
    }
    
}

# %%
score=[]
for model_name,mp in model_params.items():
    clf = GridSearchCV(mp["model"],mp["params"],cv=8,return_train_score=False)
    clf.fit(x,y)
    score.append({
        "Model" : model_name,
        "Best_Score": clf.best_score_,
        "Best_Params": clf.best_params_
    })

# %%
sj5 = pd.DataFrame(score,columns=["Model","Best_Score","Best_Params"])

# %%
sj5
# Out:
#                  Model  Best_Score                               Best_Params
# 0                  svm    0.931833                 {'C': 1, 'kernel': 'rbf'}
# 1        decision_tree    0.919789  {'criterion': 'entropy', 'max_depth': 5}
# 2        random_forest    0.931676      {'max_depth': 5, 'n_estimators': 10}
# 3          naive_bayes    0.730087                                        {}
# 4  logistic_regression    0.932927                                  {'C': 5}

# %% [markdown]
# #### So we can see that, we are getting 93% accuracy for SVM & Random Forest

# %%
from sklearn.model_selection import cross_val_score
clf_svm = SVC(kernel="rbf",C=1)
scores = cross_val_score(clf_svm,x,y,cv=8,scoring="accuracy")

# %%
scores
# Out:
# array([0.9325    , 0.9325    , 0.9325    , 0.9325    , 0.93366708,
#        0.93366708, 0.93241552, 0.93241552])

# %%
scores.mean()
# Out:
# 0.932770650813517

# %% [markdown]
# #### So we are getting 93% Accuracy for predicting the Quality of Wine

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
clf_svm1 = SVC(kernel="rbf",C=1)
clf_svm1.fit(x_train,y_train)
# Out:
# SVC(C=1)

# %%
y_pred = clf_svm1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.953125

# %% [markdown]
# #### Now Lets see the Real value and Predicted Value

# %%
accuracy_dataframe = pd.DataFrame({"y_test": y_test, "y_pred": y_pred})

# %%
accuracy_dataframe.head()
# Out:
#       y_test  y_pred
# 2069       1       1
# 3066       1       1
# 3506       1       1
# 5177       1       1
# 5994       1       1

# %%
from jupyterthemes import get_themes
from jupyterthemes.stylefx import set_nb_theme

# %%
set_nb_theme('gruvboxd')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #ebdbb2;
#  background-color: #1d2021;
#  background: #1d2021;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d2021;
#  background: #1d2021;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #fbf1c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...
